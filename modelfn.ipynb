# %%
import os
import sys
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
from pyspark.ml import Pipeline
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder, CrossValidatorModel
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.sql.functions import col, when, expr

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("GamingBehavior").getOrCreate()

df = spark.read.csv("data/train/*", header=True, inferSchema=True)

# %%
df.head(20)
# Out:
# [Row(PlayerID=9000, Age=43, Gender='Male', Location='Other', GameGenre='Strategy', PlayTimeHours=16.271118760553215, InGamePurchases=0, GameDifficulty='Medium', SessionsPerWeek=6, AvgSessionDurationMinutes=108, PlayerLevel=79, AchievementsUnlocked=25, EngagementLevel='Medium'),
#  Row(PlayerID=9001, Age=29, Gender='Female', Location='USA', GameGenre='Strategy', PlayTimeHours=5.525961380570566, InGamePurchases=0, GameDifficulty='Medium', SessionsPerWeek=5, AvgSessionDurationMinutes=144, PlayerLevel=11, AchievementsUnlocked=10, EngagementLevel='Medium'),
#  Row(PlayerID=9002, Age=22, Gender='Female', Location='USA', GameGenre='Sports', PlayTimeHours=8.223755243499511, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=16, AvgSessionDurationMinutes=142, PlayerLevel=35, AchievementsUnlocked=41, EngagementLevel='High'),
#  Row(PlayerID=9003, Age=35, Gender='Male', Location='USA', GameGenre='Action', PlayTimeHours=5.265351277318268, InGamePurchases=1, GameDifficulty='Easy', SessionsPerWeek=9, AvgSessionDurationMinutes=85, PlayerLevel=57, AchievementsUnlocked=47, EngagementLevel='Medium'),
#  Row(PlayerID=9004, Age=33, Gender='Male', Location='Europe', GameGenre='Action', PlayTimeHours=15.53194452113429, InGamePurchases=0, GameDifficulty='Medium', SessionsPerWeek=2, AvgSessionDurationMinutes=131, PlayerLevel=95, AchievementsUnlocked=37, EngagementLevel='Medium'),
#  Row(PlayerID=9005, Age=37, Gender='Male', Location='Europe', GameGenre='RPG', PlayTimeHours=20.561855414112554, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=2, AvgSessionDurationMinutes=81, PlayerLevel=74, AchievementsUnlocked=22, EngagementLevel='Low'),
#  Row(PlayerID=9006, Age=25, Gender='Male', Location='USA', GameGenre='Action', PlayTimeHours=9.752716365932255, InGamePurchases=0, GameDifficulty='Hard', SessionsPerWeek=1, AvgSessionDurationMinutes=50, PlayerLevel=13, AchievementsUnlocked=2, EngagementLevel='Low'),
#  Row(PlayerID=9007, Age=25, Gender='Female', Location='Asia', GameGenre='RPG', PlayTimeHours=4.401729344841462, InGamePurchases=0, GameDifficulty='Medium', SessionsPerWeek=10, AvgSessionDurationMinutes=48, PlayerLevel=27, AchievementsUnlocked=23, EngagementLevel='Medium'),
#  Row(PlayerID=9008, Age=38, Gender='Female', Location='Europe', GameGenre='Simulation', PlayTimeHours=18.15273259575482, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=5, AvgSessionDurationMinutes=101, PlayerLevel=23, AchievementsUnlocked=41, EngagementLevel='Medium'),
#  Row(PlayerID=9009, Age=38, Gender='Female', Location='Other', GameGenre='Sports', PlayTimeHours=23.942771725289525, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=13, AvgSessionDurationMinutes=95, PlayerLevel=99, AchievementsUnlocked=36, EngagementLevel='High'),
#  Row(PlayerID=9010, Age=17, Gender='Male', Location='USA', GameGenre='Strategy', PlayTimeHours=4.829915833543258, InGamePurchases=0, GameDifficulty='Hard', SessionsPerWeek=8, AvgSessionDurationMinutes=95, PlayerLevel=14, AchievementsUnlocked=12, EngagementLevel='High'),
#  Row(PlayerID=9011, Age=36, Gender='Female', Location='Asia', GameGenre='Simulation', PlayTimeHours=5.53598092541321, InGamePurchases=1, GameDifficulty='Easy', SessionsPerWeek=16, AvgSessionDurationMinutes=124, PlayerLevel=62, AchievementsUnlocked=31, EngagementLevel='High'),
#  Row(PlayerID=9012, Age=16, Gender='Male', Location='USA', GameGenre='Sports', PlayTimeHours=18.776233805679176, InGamePurchases=1, GameDifficulty='Easy', SessionsPerWeek=9, AvgSessionDurationMinutes=18, PlayerLevel=52, AchievementsUnlocked=32, EngagementLevel='High'),
#  Row(PlayerID=9013, Age=38, Gender='Female', Location='USA', GameGenre='Strategy', PlayTimeHours=8.701959180591404, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=0, AvgSessionDurationMinutes=156, PlayerLevel=33, AchievementsUnlocked=47, EngagementLevel='Low'),
#  Row(PlayerID=9014, Age=44, Gender='Male', Location='USA', GameGenre='Simulation', PlayTimeHours=17.975200475946355, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=8, AvgSessionDurationMinutes=41, PlayerLevel=98, AchievementsUnlocked=1, EngagementLevel='Low'),
#  Row(PlayerID=9015, Age=16, Gender='Male', Location='Europe', GameGenre='RPG', PlayTimeHours=7.9515113390570535, InGamePurchases=0, GameDifficulty='Medium', SessionsPerWeek=10, AvgSessionDurationMinutes=156, PlayerLevel=58, AchievementsUnlocked=24, EngagementLevel='High'),
#  Row(PlayerID=9016, Age=35, Gender='Male', Location='Asia', GameGenre='Strategy', PlayTimeHours=17.88789845694821, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=16, AvgSessionDurationMinutes=154, PlayerLevel=62, AchievementsUnlocked=4, EngagementLevel='High'),
#  Row(PlayerID=9017, Age=47, Gender='Male', Location='USA', GameGenre='RPG', PlayTimeHours=17.272112901806345, InGamePurchases=0, GameDifficulty='Medium', SessionsPerWeek=2, AvgSessionDurationMinutes=131, PlayerLevel=13, AchievementsUnlocked=9, EngagementLevel='Low'),
#  Row(PlayerID=9018, Age=26, Gender='Female', Location='Asia', GameGenre='Action', PlayTimeHours=19.416078735805648, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=3, AvgSessionDurationMinutes=135, PlayerLevel=77, AchievementsUnlocked=25, EngagementLevel='Medium'),
#  Row(PlayerID=9019, Age=36, Gender='Female', Location='Asia', GameGenre='RPG', PlayTimeHours=19.3388255215677, InGamePurchases=0, GameDifficulty='Easy', SessionsPerWeek=4, AvgSessionDurationMinutes=56, PlayerLevel=21, AchievementsUnlocked=30, EngagementLevel='Low')]

# %% [markdown]
# Tiền xử lí

# %%
ADDICTION_CUTOFF = 1280
RANDOM_STATE = 42
TARGET_VARIABLE = "EngagementLevel"

# %%
df_result = df.select(
    col("Age"),
    col("Gender"),
    col("Location"),
    col("GameGenre"),
    col("InGamePurchases"),
    col("SessionsPerWeek"),
    col("AvgSessionDurationMinutes"),
    col("PlayerLevel"),
    col("AchievementsUnlocked"),
    col("EngagementLevel"),
    when(col("GameDifficulty") == "Hard", "true").otherwise("false").alias("IsStressed"),
    when(col("GameDifficulty") == "Easy", 1)
        .when(col("GameDifficulty") == "Medium", 4)
        .when(col("GameDifficulty") == "Hard", 8).alias("GameDifficultyQuantified"),
)
df_result = df_result.withColumn(
    "isAddicted",
    when((col("AvgSessionDurationMinutes") * col("SessionsPerWeek")) > ADDICTION_CUTOFF, 1).otherwise(0)
)

# %%
numerical_columns = [f.name for f in df_result.schema.fields if f.dataType.typeName() in ['integer', 'double', 'long', 'float']]
categorical_columns = [c for c in df_result.columns if c not in numerical_columns + [TARGET_VARIABLE]]

# %%
indexers = [StringIndexer(inputCol=c, outputCol=c+"_idx", handleInvalid="keep") for c in categorical_columns]
encoder = OneHotEncoder(inputCols=[c+"_idx" for c in categorical_columns],
                        outputCols=[c+"_enc" for c in categorical_columns])
feature_cols = numerical_columns + [c+"_enc" for c in categorical_columns]
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
label_indexer = StringIndexer(inputCol=TARGET_VARIABLE, outputCol="label")

rf = RandomForestClassifier(featuresCol="features", labelCol="label", seed=RANDOM_STATE)

pipeline = Pipeline(stages = indexers + [encoder, label_indexer, assembler, rf])

# %% [markdown]
# train

# %%
paramGrid = ParamGridBuilder() \
    .addGrid(rf.numTrees, [100, 200]) \
    .addGrid(rf.maxDepth, [8, 10]) \
    .addGrid(rf.featureSubsetStrategy, ["sqrt"]) \
    .build()

crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=MulticlassClassificationEvaluator(labelCol="label", metricName="accuracy"),
                          numFolds=3,
                          parallelism=4,
                          seed=RANDOM_STATE)

# %%
cvModel = crossval.fit(df_result)
cvModel.write().overwrite().save("c:/Python/BTLBD/models/cv_pipeline_model")

# %%
print("Best CV-Accuracy:", max(cvModel.avgMetrics))
# Out:
# Best CV-Accuracy: 0.8815155505354973

# %% [markdown]
# Test

# %%
cvModel_loaded = CrossValidatorModel.load("c:\\Python\\BTLBD\\models\\cv_pipeline_model")

# %%
test_df = spark.read.csv("data/test/*", header=True, inferSchema=True)
test_processed = test_df.select(
    col("PlayerID"),
    col("Age"),
    col("Age"),
    col("Gender"),
    col("Location"),
    col("GameGenre"),
    col("InGamePurchases"),
    col("SessionsPerWeek"),
    col("AvgSessionDurationMinutes"),
    col("PlayerLevel"),
    col("AchievementsUnlocked"),
    when(col("GameDifficulty") == "Hard", "true").otherwise("false").alias("IsStressed"),
    when(col("GameDifficulty") == "Easy", 1)
        .when(col("GameDifficulty") == "Medium", 4)
        .when(col("GameDifficulty") == "Hard", 8).alias("GameDifficultyQuantified"),
        
)
test_processed = test_processed.withColumn(
    "isAddicted",
    when((col("AvgSessionDurationMinutes") * col("SessionsPerWeek")) > ADDICTION_CUTOFF, 1).otherwise(0)
)

# %%
predictions = cvModel_loaded.transform(test_processed)

# %%
results = predictions.select(
    col("PlayerID"),
    col("prediction").cast("int").alias("PredictedEngagement")
)

results.coalesce(1).write.mode("overwrite").option("header", "true").csv("data/results")

print("Predictions saved to data/results/")
# Out:
# Predictions saved to data/results/

# %%
results.show(20, truncate=False)
# Out:
# +--------+-------------------+
# |PlayerID|PredictedEngagement|
# +--------+-------------------+
# |9000    |0                  |
# |9001    |0                  |
# |9002    |1                  |
# |9003    |0                  |
# |9004    |0                  |
# |9005    |2                  |
# |9006    |2                  |
# |9007    |0                  |
# |9008    |0                  |
# |9009    |1                  |
# |9010    |0                  |
# |9011    |1                  |
# |9012    |2                  |
# |9013    |2                  |
# |9014    |0                  |
# |9015    |1                  |
# |9016    |1                  |
# |9017    |2                  |
# |9018    |0                  |
# |9019    |2                  |
# +--------+-------------------+
# only showing top 20 rows
